# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # MLflow Classification Recipe Notebook
#
# This notebook runs the MLflow Classification Recipe on Databricks and inspects its results. For more information about the MLflow Classification Recipe, including usage examples, see the [Classification Recipe overview documentation](https://mlflow.org/docs/latest/recipes.html#classification-recipe) the [Classification Recipe API documentation](https://mlflow.org/docs/latest/python_api/mlflow.recipes.html#module-mlflow.recipes.classification.v1.recipe).

# %%
from mlflow.recipes import Recipe

r = Recipe(profile="local")
# Out:
# 2022/11/12 01:00:29 INFO mlflow.recipes.recipe: Creating MLflow Recipe 'recipes-classification-template' with profile: 'local'

# %%
r.inspect()
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <body>
#     <style>
#       @keyframes spin {
#         to { transform: translate(calc(-50%), calc(50vh - 50%)) rotate(360deg); }
#       }
#       .mermaidTooltip {
#         display: none;
#       }
#       .wrapper {
#         display: flex;
#       }
#       .mermaid {
#         width: 60%;
#       }
#       .pane-loading {
#         font-size: 0;
#         color: transparent;
#       }
#       .pane-loading::after {
#         content: "";
#         position: absolute;
#         inset: 0 50%;
#         width: 32px;
#         height: 32px;
#         transform: translate(calc(-50%), calc(50vh - 50%));
#         border: 0.25rem solid #9370DB;
#         border-bottom: 0.25rem solid rgba(0,0,0,0);
#         border-radius: 50%;
#         animation: spin 1s linear infinite;
#       }
#       #editor {
#         font-size: 13px;
#         width: 40%;
#         position: relative;
#       }
#       font {
#         font-size: 24px;
#         padding: 24px;
#       }
#       .node:hover {
#         stroke: #2272B4 !important;
#         color: #0E538B !important;
#         background-color: #bbdaf4;
#       }
#     </style>
#
#     <div class="wrapper">
#       <div class="mermaid pane-loading">
#           flowchart TD
#
#           subgraph " "
#             recipe([recipe.yaml])
#
#             ingestUserCode([steps/ingest.py]) --> ingestMLPStep[["<font>ingest</font>"]]
#             ingestMLPStep --> dataParquet[(ingested_data)]
#
#             ingestScoringUserCode([steps/ingest.py]) --> ingestScoringMLPStep[["<font>ingest_scoring</font>"]]
#             ingestScoringMLPStep --> dataScoringParquet[(ingested_scoring_data)]
#
#             dataScoring[(ingested_scoring_data)] --> predictMLPStep[["<font>predict</font>"]]
#             predictMLPStep --> dataScored[(scored_data)]
#           end
#
#           data[(ingested_data)] --> splitStep[["<font>split</font>"]]
#           transformUserCode([steps/transform.py]) --> transformMLPStep
#           splitUserCode([steps/split.py]) --> splitStep
#           splitStep --> splitData0[(training_data)]
#           splitStep --> splitData1[(validation_data)]
#           splitStep --> splitData2[(test_data)]
#           splitData0 --> transformMLPStep[["<font>transform</font>"]]
#           splitData1 --> transformMLPStep[["<font>transform</font>"]]
#
#           transformMLPStep --> transformedParquet[(transformed_training_data, <br/> transformed_validation_data)]
#           transformMLPStep --> transformer
#           transformedParquet --> trainMLPStep[["<font>train</font>"]]
#
#           trainUserCode([steps/train.py]) --> trainMLPStep
#           customMetricsUserCode([steps/custom_metrics.py]) --> trainMLPStep
#           transformer --> trainMLPStep
#           trainMLPStep --> run
#           trainMLPStep --> model
#           trainMLPStep --> predictedTrainingData[(predicted_training_data)]
#
#           model --> evaluateMLPStep[["<font>evaluate</font>"]]
#           splitData1 --> evaluateMLPStep
#           splitData2 --> evaluateMLPStep
#           customMetricsUserCode --> evaluateMLPStep
#           evaluateMLPStep --> model_validation_status
#           run --> registerMLPStep[["<font>register</font>"]]
#           run --> evaluateMLPStep
#
#           model_validation_status --> registerMLPStep
#           registerMLPStep --> registered_model_version
#
#           click ingestMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;ingest&bsol;&#39; step resolves the dataset specified by the &bsol;&#39;data&bsol;&#39; section in recipe.yaml and converts it to parquet format, leveraging the custom dataset parsing code defined in `steps/ingest.py` (and referred to by the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;data&bsol;&#39; section in recipe.yaml) if necessary. Subsequent steps convert this dataset into training, validation, & test sets and use them to develop a model. An example recipe.yaml &bsol;&#39;data&bsol;&#39; configuration is shown below.\n\ndata:\n  location: https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2022-01.parquet\n  format: {{INGEST_DATA_FORMAT|default(&bsol;&#39;parquet&bsol;&#39;)}}\n  loader_method: load_file_as_dataframe\n', 'help_string_type': 'text'}"
#           click ingestUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/ingest.py defines customizable logic for parsing arbitrary dataset formats (i.e. formats that are not natively parsed by MLflow Recipes) via the `load_file_as_dataframe` function. Note that the Parquet, Delta, and Spark SQL dataset formats are natively parsed by MLflow Recipes, and you do not need to define custom logic for parsing them. An example `load_file_as_dataframe` implementation is displayed below (note that a different function name or module can be specified via the &bsol;&#39;loader_method&bsol;&#39; attribute of the &bsol;&#39;data&bsol;&#39; section in recipe.yaml).\n&bsol;#quot;&bsol;#quot;&bsol;#quot;\n\ndef load_file_as_dataframe(\n    file_path: str,\n    file_format: str,\n) -> pandas.DataFrame:\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n    Load content from the specified dataset file as a Pandas DataFrame.\n\n    This method is used to load dataset types that are not natively  managed by MLflow Recipes (datasets that are not in Parquet, Delta Table, or Spark SQL Table format). This method is called once for each file in the dataset, and MLflow Recipes automatically combines the resulting DataFrames together.\n\n    :param file_path: The path to the dataset file.\n    :param file_format: The file format string, such as &bsol;#quot;csv&bsol;#quot;.\n    :return: A Pandas DataFrame representing the content of the specified file.\n    &bsol;#quot;&bsol;#quot;&bsol;#quot;\n', 'help_string_type': 'python'}"
#           click splitStep renderMoreInformation "{'help_string': 'The &bsol;&#39;split&bsol;&#39; step splits the ingested dataset produced by the &bsol;&#39;ingest&bsol;&#39; step into a training dataset for model training, a validation dataset for model performance evaluation & tuning, and a test dataset for model performance evaluation. The fraction of records allocated to each dataset is defined by the &bsol;&#39;split_ratios&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml. The split step also preprocesses the datasets using logic defined in `steps/split.py` (and referred to by the &bsol;&#39;post_split_method&bsol;&#39; attribute of the &bsol;&#39;split&bsol;&#39; step definition in recipe.yaml). Subsequent steps use these datasets to develop a model and measure its performance. An example recipe.yaml &bsol;&#39;split&bsol;&#39; step definition is shown below.\n\nsteps:\n  split:\n    split_ratios: {{SPLIT_RATIOS|default([0.75, 0.125, 0.125])}}\n    post_split_method: process_splits\n', 'help_string_type': 'text'}"
#           click transformMLPStep renderMoreInformation "{'help_string': 'The &bsol;&#39;transform&bsol;&#39; step uses the training dataset produced by &bsol;&#39;split&bsol;&#39; to fit a transformer with the transformation operations defined in `steps/transform.py` (and referred to by the &bsol;&#39;transformer_method&bsol;&#39; attribute of the &bsol;&#39;transform&bsol;&#39; step definition in recipe.yaml). The transformer is then applied to the training dataset and the validation dataset, producing transformed datasets that are used by subsequent steps for estimator training and model performance evaluation. An example recipe.yaml &bsol;&#39;transform&bsol;&#39; step definition is shown below.\n\nsteps:\n  transform:\n    transformer_method: transformer_fn\n', 'help_string_type': 'text'}"
#           click transformUserCode renderMoreInformation "{'help_string': '&bsol;#quot;&bsol;#quot;&bsol;#quot;\nsteps/transform.py defines customizable logic for transforming input data during model inference. Transformations are specified via the via the `transformer_fn` function, an example of which is displayed below (note that a different function name or module can be specified via the &bsol;&#39;transformer_method&bsol;&#39; attribute of

# %%
r.run("ingest")
# Out:
# 2022/11/12 01:00:30 INFO mlflow.recipes.step: Running step ingest...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Ingest@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-dy3iqe">
#
#                     <button id=0 class="tablink-dy3iqe">
#                         Data Profile
#                     </button>
#
#                     <button id=1 class="tablink-dy3iqe">
#                         Data Schema
#                     </button>
#
#                     <button id=2 class="tablink-dy3iqe">
#                         Data Preview
#                     </button>
#
#                     <button id=3 class="tablink-dy3iqe">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-dy3iqe content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-dy3iqe content-hide"><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_fd23b table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_fd23b  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_fd23b  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_fd23b" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_fd23b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_fd23b_level0_col1" class="col_heading level0 col1" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd23b_row0_col0" class="data row0 col0" >mean radius</td>
#       <td id="T_fd23b_row0_col1" class="data row0 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row1_col0" class="data row1 col0" >mean texture</td>
#       <td id="T_fd23b_row1_col1" class="data row1 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row2_col0" class="data row2 col0" >mean perimeter</td>
#       <td id="T_fd23b_row2_col1" class="data row2 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row3_col0" class="data row3 col0" >mean area</td>
#       <td id="T_fd23b_row3_col1" class="data row3 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row4_col0" class="data row4 col0" >mean smoothness</td>
#       <td id="T_fd23b_row4_col1" class="data row4 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row5_col0" class="data row5 col0" >mean compactness</td>
#       <td id="T_fd23b_row5_col1" class="data row5 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row6_col0" class="data row6 col0" >mean concavity</td>
#       <td id="T_fd23b_row6_col1" class="data row6 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row7_col0" class="data row7 col0" >mean concave points</td>
#       <td id="T_fd23b_row7_col1" class="data row7 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row8_col0" class="data row8 col0" >mean symmetry</td>
#       <td id="T_fd23b_row8_col1" class="data row8 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row9_col0" class="data row9 col0" >mean fractal dimension</td>
#       <td id="T_fd23b_row9_col1" class="data row9 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row10_col0" class="data row10 col0" >radius error</td>
#       <td id="T_fd23b_row10_col1" class="data row10 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row11_col0" class="data row11 col0" >texture error</td>
#       <td id="T_fd23b_row11_col1" class="data row11 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row12_col0" class="data row12 col0" >perimeter error</td>
#       <td id="T_fd23b_row12_col1" class="data row12 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row13_col0" class="data row13 col0" >area error</td>
#       <td id="T_fd23b_row13_col1" class="data row13 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row14_col0" class="data row14 col0" >smoothness error</td>
#       <td id="T_fd23b_row14_col1" class="data row14 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row15_col0" class="data row15 col0" >compactness error</td>
#       <td id="T_fd23b_row15_col1" class="data row15 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row16_col0" class="data row16 col0" >concavity error</td>
#       <td id="T_fd23b_row16_col1" class="data row16 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row17_col0" class="data row17 col0" >concave points error</td>
#       <td id="T_fd23b_row17_col1" class="data row17 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row18_col0" class="data row18 col0" >symmetry error</td>
#       <td id="T_fd23b_row18_col1" class="data row18 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row19_col0" class="data row19 col0" >fractal dimension error</td>
#       <td id="T_fd23b_row19_col1" class="data row19 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row20_col0" class="data row20 col0" >worst radius</td>
#       <td id="T_fd23b_row20_col1" class="data row20 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row21_col0" class="data row21 col0" >worst texture</td>
#       <td id="T_fd23b_row21_col1" class="data row21 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row22_col0" class="data row22 col0" >worst perimeter</td>
#       <td id="T_fd23b_row22_col1" class="data row22 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23b_row23_col0" class="data row23 col0" >worst area</td>
#       <td id="T_fd23b_row23_col1" class="data row23 col1" >number</td>
#     </tr>
#     <tr>
#       <td id="T_fd23

# %%
r.run("split")
# Out:
# 2022/11/12 01:00:30 INFO mlflow.recipes.utils.execution: ingest: No changes. Skipping.
# 2022/11/12 01:00:31 INFO mlflow.recipes.step: Running step split...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Split@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-k9h3yn">
#
#                     <button id=0 class="tablink-k9h3yn">
#                         Compare Splits
#                     </button>
#
#                     <button id=1 class="tablink-k9h3yn">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-k9h3yn content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-k9h3yn content-hide">
#
#                 <p><strong>Number of train dataset rows:</strong> <code>410</code></p>
#                 <p><strong>Number of validation dataset rows:</strong> <code>73</code></p>
#                 <p><strong>Number of test dataset rows:</strong> <code>86</code></p>
#                 <p><strong>Number of dropped rows:</strong> <code>0</code></p>
#                 <p><strong>Run duration (s)</strong>: 0.217</p>
#                 <p><strong>Last updated:</strong> 2022-11-12 01:00:31</p>
#                 </div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-k9h3yn");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-k9h3yn");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-k9h3yn")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-k9h3yn");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-k9h3yn");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>

# %%
training_data = r.get_artifact("training_data")
training_data.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   410.000000    410.000000      410.000000   410.000000
# mean     14.244073     19.391293       92.752683   663.897805
# std       3.465521      4.352865       23.919776   347.986779
# min       7.691000      9.710000       47.920000   170.400000
# 25%      11.817500     16.217500       76.110000   429.650000
# 50%      13.535000     19.040000       87.480000   564.200000
# 75%      15.772500     21.907500      104.025000   782.200000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       410.000000        410.000000      410.000000           410.000000
# mean          0.096651          0.105241        0.089447             0.049832
# std           0.014211          0.053345        0.078927             0.038719
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086575          0.065307        0.029500             0.020682
# 50%           0.095895          0.095275        0.066145             0.037135
# 75%           0.105400          0.130600        0.132250             0.074022
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     410.000000              410.000000  ...     410.000000
# mean        0.181465                0.062770  ...      25.797415
# std         0.027456                0.007046  ...       6.311756
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161925                0.057485  ...      21.065000
# 50%         0.179950                0.061400  ...      25.485000
# 75%         0.196600                0.066210  ...      30.217500
# max         0.290600                0.095750  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       410.000000   410.000000        410.000000         410.000000
# mean        108.086390   891.061707          0.132701           0.258820
# std          33.001822   557.259419          0.022760           0.164261
# min          54.490000   223.600000          0.071170           0.027290
# 25%          85.100000   522.000000          0.117200           0.148500
# 50%          99.165000   705.900000          0.131600           0.214850
# 75%         125.775000  1083.500000          0.146700           0.342575
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       410.000000            410.000000      410.000000
# mean          0.275265              0.116329        0.291370
# std           0.210304              0.066064        0.063839
# min           0.000000              0.000000        0.156500
# 25%           0.116475              0.065028        0.250050
# 50%           0.226550              0.101600        0.283100
# 75%           0.387550              0.166200        0.320500
# max           1.170000              0.291000        0.577400
#
#        worst fractal dimension      target
# count               410.000000  410.000000
# mean                  0.084303    0.614634
# std                   0.018670    0.487276
# min                   0.055040    0.000000
# 25%                   0.071557    0.000000
# 50%                   0.080075    1.000000
# 75%                   0.092202    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
r.run("transform")
# Out:
# 2022/11/12 01:00:32 INFO mlflow.recipes.utils.execution: ingest, split: No changes. Skipping.
# 2022/11/12 01:00:32 INFO mlflow.recipes.step: Running step transform...
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Transform@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-m7f0by">
#
#                     <button id=0 class="tablink-m7f0by">
#                         Data Profile (Train Transformed)
#                     </button>
#
#                     <button id=1 class="tablink-m7f0by">
#                         Transformer
#                     </button>
#
#                     <button id=2 class="tablink-m7f0by">
#                         Input Schema
#                     </button>
#
#                     <button id=3 class="tablink-m7f0by">
#                         Output Schema
#                     </button>
#
#                     <button id=4 class="tablink-m7f0by">
#                         Data Preview
#                     </button>
#
#                     <button id=5 class="tablink-m7f0by">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-m7f0by content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;import&quot; href=&quot;https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html&quot; &gt;
#         &lt;facets-overview id=&quot;facets&quot; proto-input=&quot;...&quot; compare-mode=&quot;True&quot;&gt;&lt;/facets-overview&gt;
#         &lt;/div&gt;
#     ' width='100%' height='500' frameborder='0'></iframe></div>
#
#                 <div class="content-m7f0by content-hide"><style>#sk-container-id-1 {color: black;background-color: white;}#sk-container-id-1 pre{padding: 0;}#sk-container-id-1 div.sk-toggleable {background-color: white;}#sk-container-id-1 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-1 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-1 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-1 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-1 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-1 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-1 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-width: 100%;overflow: auto;}#sk-container-id-1 input.sk-toggleable__control:checked~label.sk-toggleable__label-arrow:before {content: "▾";}#sk-container-id-1 div.sk-estimator input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-label input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 input.sk-hidden--visually {border: 0;clip: rect(1px 1px 1px 1px);clip: rect(1px, 1px, 1px, 1px);height: 1px;margin: -1px;overflow: hidden;padding: 0;position: absolute;width: 1px;}#sk-container-id-1 div.sk-estimator {font-family: monospace;background-color: #f0f8ff;border: 1px dotted black;border-radius: 0.25em;box-sizing: border-box;margin-bottom: 0.5em;}#sk-container-id-1 div.sk-estimator:hover {background-color: #d4ebff;}#sk-container-id-1 div.sk-parallel-item::after {content: "";width: 100%;border-bottom: 1px solid gray;flex-grow: 1;}#sk-container-id-1 div.sk-label:hover label.sk-toggleable__label {background-color: #d4ebff;}#sk-container-id-1 div.sk-serial::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: 0;}#sk-container-id-1 div.sk-serial {display: flex;flex-direction: column;align-items: center;background-color: white;padding-right: 0.2em;padding-left: 0.2em;position: relative;}#sk-container-id-1 div.sk-item {position: relative;z-index: 1;}#sk-container-id-1 div.sk-parallel {display: flex;align-items: stretch;justify-content: center;background-color: white;position: relative;}#sk-container-id-1 div.sk-item::before, #sk-container-id-1 div.sk-parallel-item::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 0;bottom: 0;left: 50%;z-index: -1;}#sk-container-id-1 div.sk-parallel-item {display: flex;flex-direction: column;z-index: 1;position: relative;background-color: white;}#sk-container-id-1 div.sk-parallel-item:first-child::after {align-self: flex-end;width: 50%;}#sk-container-id-1 div.sk-parallel-item:last-child::after {align-self: flex-start;width: 50%;}#sk-container-id-1 div.sk-parallel-item:only-child::after {width: 0;}#sk-container-id-1 div.sk-dashed-wrapped {border: 1px dashed gray;margin: 0 0.4em 0.5em 0.4em;box-sizing: border-box;padding-bottom: 0.4em;background-color: white;}#sk-container-id-1 div.sk-label label {font-family: monospace;font-weight: bold;display: inline-block;line-height: 1.2em;}#sk-container-id-1 div.sk-label-container {text-align: center;}#sk-container-id-1 div.sk-container {/* jupyter's `normalize.less` sets `[hidden] { display: none; }` but bootstrap.min.css set `[hidden] { display: none !important; }` so we also need the `!important` here to be able to override the default hidden behavior on the sphinx rendered scikit-learn.org. See: https://github.com/scikit-learn/scikit-learn/issues/21755 */display: inline-block !important;position: rela ...

# %%
r.run("train")
# Out:
# 2022/11/12 01:00:33 INFO mlflow.recipes.utils.execution: ingest, split, transform: No changes. Skipping.
# 2022/11/12 01:00:33 INFO mlflow.recipes.step: Running step train...
# 2022/11/12 01:00:34 INFO mlflow.recipes.steps.train: Training data has less than 5000 rows, skipping rebalancing.
# [flaml.automl: 11-12 01:00:34] {2600} INFO - task = classification
# [flaml.automl: 11-12 01:00:34] {2602} INFO - Data split method: stratified
# [flaml.automl: 11-12 01:00:34] {2605} INFO - Evaluation method: cv
# [flaml.automl: 11-12 01:00:34] {2727} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl: 11-12 01:00:34] {2869} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 0, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3297} INFO - Estimated sufficient time budget=264s. Estimated necessary time budget=6s.
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.0s,	estimator lgbm's best error=0.0902,	best estimator lgbm's best error=0.0902
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 1, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.1s,	estimator lgbm's best error=0.0902,	best estimator lgbm's best error=0.0902
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 2, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.1s,	estimator lgbm's best error=0.0610,	best estimator lgbm's best error=0.0610
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 3, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.2s,	estimator lgbm's best error=0.0537,	best estimator lgbm's best error=0.0537
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 4, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.3s,	estimator lgbm's best error=0.0537,	best estimator lgbm's best error=0.0537
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 5, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.3s,	estimator lgbm's best error=0.0415,	best estimator lgbm's best error=0.0415
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 6, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.4s,	estimator lgbm's best error=0.0415,	best estimator lgbm's best error=0.0415
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 7, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.4s,	estimator lgbm's best error=0.0415,	best estimator lgbm's best error=0.0415
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 8, current learner lgbm
# [flaml.automl: 11-12 01:00:34] {3344} INFO -  at 0.4s,	estimator lgbm's best error=0.0293,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:34] {3164} INFO - iteration 9, current learner xgboost
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.5s,	estimator xgboost's best error=0.0634,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 10, current learner extra_tree
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.5s,	estimator extra_tree's best error=0.0976,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 11, current learner rf
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.6s,	estimator rf's best error=0.0756,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 12, current learner rf
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.6s,	estimator rf's best error=0.0537,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 13, current learner xgboost
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.7s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 14, current learner rf
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.7s,	estimator rf's best error=0.0537,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 15, current learner extra_tree
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.7s,	estimator extra_tree's best error=0.0610,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 16, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.8s,	estimator lgbm's best error=0.0293,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 17, current learner extra_tree
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.8s,	estimator extra_tree's best error=0.0610,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 18, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.8s,	estimator lgbm's best error=0.0293,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 19, current learner rf
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.9s,	estimator rf's best error=0.0537,	best estimator lgbm's best error=0.0293
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 20, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 0.9s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 21, current learner rf
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.0s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 22, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.0s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 23, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.1s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 24, current learner extra_tree
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.2s,	estimator extra_tree's best error=0.0610,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.2s,	estimator extra_tree's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 26, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.2s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 27, current learner lgbm
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.3s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 28, current learner xgboost
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.3s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 29, current learner xgboost
# [flaml.automl: 11-12 01:00:35] {3344} INFO -  at 1.4s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:35] {3164} INFO - iteration 30, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 31, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 32, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 33, current learner xgboost
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.6s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 34, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.6s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 35, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.7s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 36, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.7s,	estimator extra_tree's best error=0.0561,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 37, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.7s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 38, current learner rf
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.8s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 39, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.8s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 40, current learner rf
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.9s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 41, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.9s,	estimator extra_tree's best error=0.0561,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 42, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 1.9s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 43, current learner rf
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.0s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.1s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 45, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.1s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 46, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.2s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 47, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.2s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 48, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.3s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 49, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.3s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 50, current learner extra_tree
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.4s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 51, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.4s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 52, current learner lgbm
# [flaml.automl: 11-12 01:00:36] {3344} INFO -  at 2.4s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:36] {3164} INFO - iteration 53, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 2.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 54, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 2.9s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 55, current learner xgboost
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 2.9s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 56, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.0s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 57, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.0s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 58, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.0s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 59, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.1s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 60, current learner rf
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.1s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 61, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.2s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 62, current learner xgboost
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.2s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 63, current learner extra_tree
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.3s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 64, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.3s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 65, current learner lgbm
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.4s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 66, current learner xgboost
# [flaml.automl: 11-12 01:00:37] {3344} INFO -  at 3.4s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:37] {3164} INFO - iteration 67, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 68, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 69, current learner rf
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.6s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 70, current learner xgboost
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.6s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 71, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.7s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 72, current learner extra_tree
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.8s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 73, current learner rf
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.8s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 74, current learner extra_tree
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.8s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 75, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.9s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 76, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 3.9s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 77, current learner extra_tree
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.0s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 78, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.0s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 79, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.1s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 80, current learner extra_tree
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.1s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 81, current learner lgbm
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.2s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 82, current learner xgboost
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.2s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 83, current learner xgboost
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.3s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 84, current learner extra_tree
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.4s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 85, current learner rf
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.4s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 86, current learner xgboost
# [flaml.automl: 11-12 01:00:38] {3344} INFO -  at 4.4s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:38] {3164} INFO - iteration 87, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 88, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.5s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 89, current learner extra_tree
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.6s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 90, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.6s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 91, current learner extra_tree
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.7s,	estimator extra_tree's best error=0.0488,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 92, current learner rf
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.8s,	estimator rf's best error=0.0512,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 93, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.8s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 94, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.8s,	estimator lgbm's best error=0.0268,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 95, current learner extra_tree
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.9s,	estimator extra_tree's best error=0.0463,	best estimator lgbm's best error=0.0268
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 96, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 4.9s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 97, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.0s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 98, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.1s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 99, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.1s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 100, current learner xgboost
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.2s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 101, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.3s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 102, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.3s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 103, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.4s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 104, current learner lgbm
# [flaml.automl: 11-12 01:00:39] {3344} INFO -  at 5.4s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:39] {3164} INFO - iteration 105, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.5s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 106, current learner xgboost
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.5s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 107, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.6s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 108, current learner xgboost
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.7s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 109, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.8s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 110, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.8s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 111, current learner extra_tree
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.9s,	estimator extra_tree's best error=0.0463,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 112, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 5.9s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 113, current learner extra_tree
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.1s,	estimator extra_tree's best error=0.0463,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 114, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.1s,	estimator lgbm's best error=0.0244,	best estimator lgbm's best error=0.0244
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 115, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.1s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 116, current learner rf
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.2s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 117, current learner rf
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.3s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 118, current learner lgbm
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.3s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 119, current learner rf
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.4s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 120, current learner rf
# [flaml.automl: 11-12 01:00:40] {3344} INFO -  at 6.4s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:40] {3164} INFO - iteration 121, current learner rf
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.5s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 122, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.5s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 123, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.6s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 124, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.7s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 125, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.8s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 126, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.8s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 127, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.9s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 128, current learner rf
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 6.9s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 129, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.0s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 130, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.1s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 131, current learner rf
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.1s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 132, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.2s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 133, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.3s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 134, current learner lgbm
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.3s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 135, current learner xgboost
# [flaml.automl: 11-12 01:00:41] {3344} INFO -  at 7.4s,	estimator xgboost's best error=0.0585,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:41] {3164} INFO - iteration 136, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.5s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 137, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.6s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 138, current learner rf
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.6s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 139, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.7s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 140, current learner rf
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.7s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 141, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.8s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 142, current learner rf
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.9s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 143, current learner rf
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 7.9s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 144, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.0s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 145, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.1s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 146, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.1s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 147, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.2s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 148, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.2s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 149, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.3s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 150, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.3s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 151, current learner rf
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.4s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 152, current learner lgbm
# [flaml.automl: 11-12 01:00:42] {3344} INFO -  at 8.4s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:42] {3164} INFO - iteration 153, current learner lgbm
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.5s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 154, current learner lgbm
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.5s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 155, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.6s,	estimator extra_tree's best error=0.0390,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 156, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.7s,	estimator extra_tree's best error=0.0390,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 157, current learner lgbm
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.8s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 158, current learner xgb_limitdepth
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.9s,	estimator xgb_limitdepth's best error=0.0512,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 159, current learner xgb_limitdepth
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 8.9s,	estimator xgb_limitdepth's best error=0.0512,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 160, current learner xgb_limitdepth
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.0s,	estimator xgb_limitdepth's best error=0.0512,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 161, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.0s,	estimator extra_tree's best error=0.0390,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 162, current learner xgb_limitdepth
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.1s,	estimator xgb_limitdepth's best error=0.0512,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 163, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.1s,	estimator extra_tree's best error=0.0390,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 164, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.2s,	estimator extra_tree's best error=0.0366,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 165, current learner lgbm
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.2s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 166, current learner rf
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.3s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 167, current learner rf
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.3s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 168, current learner extra_tree
# [flaml.automl: 11-12 01:00:43] {3344} INFO -  at 9.4s,	estimator extra_tree's best error=0.0366,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:43] {3164} INFO - iteration 169, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.5s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 170, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.6s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 171, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.6s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 172, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.7s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 173, current learner rf
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.7s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 174, current learner rf
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.8s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 175, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.8s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 176, current learner extra_tree
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.9s,	estimator extra_tree's best error=0.0366,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 177, current learner rf
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 9.9s,	estimator rf's best error=0.0415,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 178, current learner lgbm
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 10.0s,	estimator lgbm's best error=0.0220,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3164} INFO - iteration 179, current learner lrl1
# [flaml.automl: 11-12 01:00:44] {3344} INFO -  at 10.0s,	estimator lrl1's best error=0.0935,	best estimator lgbm's best error=0.0220
# [flaml.automl: 11-12 01:00:44] {3608} INFO - retrain lgbm for 0.0s
# [flaml.automl: 11-12 01:00:44] {3615} INFO - retrained model: LGBMClassifier(colsample_bytree=0.6805235130537369,
#                learning_rate=0.2723079358724437, max_bin=255,
#                min_child_samples=3, n_estimators=76, num_leaves=4,
#                reg_alpha=0.0009765625, reg_lambda=0.0009765625, verbose=-1)
# [flaml.automl: 11-12 01:00:44] {2900} INFO - fit succeeded
# [flaml.automl: 11-12 01:00:44] {2901} INFO - Time taken to find the best model: 6.137526273727417
# 2022/11/12 01:00:44 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of xgboost. If you encounter errors during autologging, try upgrading / downgrading xgboost to a supported version, or try upgrading MLflow.
# 2022/11/12 01:00:44 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2022/11/12 01:00:44 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/11/12 01:00:44 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2022/11/12 01:00:44 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.
# 2022/11/12 01:00:46 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2022/11/12 01:00:47 WARNING mlflow.models.model: Logging model metadata to the tracking server has failed, possibly due older server version. The model artifacts have been logged successfully under ./metadata/mlflow/mlartifacts/62f37034b8b545b8a2da98d80e631487/artifacts. In addition to exporting model artifacts, MLflow clients 1.7.0 and above attempt to record model metadata to the tracking store. If logging to a mlflow server via REST, consider upgrading the server version to MLflow 1.7.0 or above. Set logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)` to see the full traceback.
# 2022/11/12 01:00:48 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/12 01:00:48 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
# 2022/11/12 01:00:49 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/12 01:00:49 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Train@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-zplwku">
#
#                     <button id=0 class="tablink-zplwku">
#                         Model Performance
#                     </button>
#
#                     <button id=1 class="tablink-zplwku">
#                         Data Profile (Predictions)
#                     </button>
#
#                     <button id=2 class="tablink-zplwku">
#                         Model Architecture
#                     </button>
#
#                     <button id=3 class="tablink-zplwku">
#                         Model Schema
#                     </button>
#
#                     <button id=4 class="tablink-zplwku">
#                         Worst Predictions
#                     </button>
#
#                     <button id=5 class="tablink-zplwku">
#                         Data Profile (Worst vs Train)
#                     </button>
#
#                     <button id=6 class="tablink-zplwku">
#                         Leaderboard
#                     </button>
#
#                     <button id=7 class="tablink-zplwku">
#                         Best Parameters  (AutoML)
#                     </button>
#
#                     <button id=8 class="tablink-zplwku">
#                         Warning Logs
#                     </button>
#
#                     <button id=9 class="tablink-zplwku">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-zplwku content-hide"><h3 class='section-title'>Summary Metrics (Validation)</h3><div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_132dd table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_132dd  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_132dd  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_132dd_row0_col0, #T_132dd_row0_col1, #T_132dd_row0_col2, #T_132dd_row1_col0, #T_132dd_row1_col1, #T_132dd_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_132dd" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_132dd_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_132dd_level0_col1" class="col_heading level0 col1" >training</th>
#       <th id="T_132dd_level0_col2" class="col_heading level0 col2" >validation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_132dd_row0_col0" class="data row0 col0" >accuracy_score</td>
#       <td id="T_132dd_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_132dd_row0_col2" class="data row0 col2" >0.945205</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row1_col0" class="data row1 col0" >custom_metric</td>
#       <td id="T_132dd_row1_col1" class="data row1 col1" >0.5</td>
#       <td id="T_132dd_row1_col2" class="data row1 col2" >0.5</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row2_col0" class="data row2 col0" >example_count</td>
#       <td id="T_132dd_row2_col1" class="data row2 col1" >410</td>
#       <td id="T_132dd_row2_col2" class="data row2 col2" >73</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row3_col0" class="data row3 col0" >f1_score</td>
#       <td id="T_132dd_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_132dd_row3_col2" class="data row3 col2" >0.955556</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row4_col0" class="data row4 col0" >false_negatives</td>
#       <td id="T_132dd_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_132dd_row4_col2" class="data row4 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row5_col0" class="data row5 col0" >false_positives</td>
#       <td id="T_132dd_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_132dd_row5_col2" class="data row5 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row6_col0" class="data row6 col0" >log_loss</td>
#       <td id="T_132dd_row6_col1" class="data row6 col1" >0.000220952</td>
#       <td id="T_132dd_row6_col2" class="data row6 col2" >0.166907</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row7_col0" class="data row7 col0" >precision_recall_auc</td>
#       <td id="T_132dd_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_132dd_row7_col2" class="data row7 col2" >0.995552</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row8_col0" class="data row8 col0" >precision_score</td>
#       <td id="T_132dd_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_132dd_row8_col2" class="data row8 col2" >0.955556</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row9_col0" class="data row9 col0" >recall_score</td>
#       <td id="T_132dd_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_132dd_row9_col2" class="data row9 col2" >0.955556</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row10_col0" class="data row10 col0" >roc_auc</td>
#       <td id="T_132dd_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_132dd_row10_col2" class="data row10 col2" >0.992857</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row11_col0" class="data row11 col0" >score</td>
#       <td id="T_132dd_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_132dd_row11_col2" class="data row11 col2" >0.945205</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row12_col0" class="data row12 col0" >true_negatives</td>
#       <td id="T_132dd_row12_col1" class="data row12 col1" >158</td>
#       <td id="T_132dd_row12_col2" class="data row12 col2" >26</td>
#     </tr>
#     <tr>
#       <td id="T_132dd_row13_col0" class="data row13 col0" >true_positives</td>
#       <td id="T_132dd_row13_col1" class="data row13 col1" >252</td>
#       <td id="T_132dd_row13_col2" class="data row13 col2" >43</td>
#     </tr>
#   </tbody>
# </table>
# </div> </div>
#
#                 <div class="content-zplwku content-hide"><iframe srcdoc='
#         &lt;div style=&quot;background-color: white&quot;&gt;
#         &lt;script&gt;!function(){let t=window.URL;window.URL=function(n,e){return&quot;string&quot;==typeof e&amp;&amp;e.startsWith(&quot;blob:&quot;)?new URL(e):new t(n,e)}}();&lt;/script&gt;
#         &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js&quot;&gt

# %%
trained_model = r.get_artifact("model")
print(trained_model)
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: train/model
#   flavor: mlflow.sklearn
#   run_id: 62f37034b8b545b8a2da98d80e631487

# %%
r.run("evaluate")
# Out:
# 2022/11/12 01:00:51 INFO mlflow.recipes.utils.execution: ingest, split, transform, train: No changes. Skipping.
# 2022/11/12 01:00:51 INFO mlflow.recipes.step: Running step evaluate...
# 2022/11/12 01:00:52 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/12 01:00:52 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
# 2022/11/12 01:00:53 INFO mlflow.models.evaluation.default_evaluator: Shap explainer _PatchedKernelExplainer is used.
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.66it/s]
#  30%|███       | 3/10 [00:00<00:01,  6.94it/s]
#  40%|████      | 4/10 [00:00<00:00,  6.13it/s]
#  50%|█████     | 5/10 [00:00<00:00,  5.80it/s]
#  60%|██████    | 6/10 [00:00<00:00,  5.61it/s]
#  70%|███████   | 7/10 [00:01<00:00,  5.44it/s]
#  80%|████████  | 8/10 [00:01<00:00,  5.27it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  5.39it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.51it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.73it/s]
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# 2022/11/12 01:00:57 INFO mlflow.models.evaluation.base: Evaluating the model with the default evaluator.
# 2022/11/12 01:00:57 INFO mlflow.models.evaluation.default_evaluator: The evaluation dataset is inferred as binary dataset, positive label is 1, negative label is 0.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Evaluate@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-lx57z5">
#
#                     <button id=0 class="tablink-lx57z5">
#                         Model Performance (Test)
#                     </button>
#
#                     <button id=1 class="tablink-lx57z5">
#                         Model Validation
#                     </button>
#
#                     <button id=2 class="tablink-lx57z5">
#                         Classifier Plots on the Validation Dataset
#                     </button>
#
#                     <button id=3 class="tablink-lx57z5">
#                         Feature Importance
#                     </button>
#
#                     <button id=4 class="tablink-lx57z5">
#                         Warning Logs
#                     </button>
#
#                     <button id=5 class="tablink-lx57z5">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-lx57z5 content-hide"><h3 class='section-title'>Summary Metrics</h3><b>NOTE</b>: Use evaluation metrics over test dataset with care. Fine-tuning model over the test dataset is not advised.<div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_12b7e table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_12b7e  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_12b7e  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_12b7e_row0_col0, #T_12b7e_row0_col1, #T_12b7e_row0_col2, #T_12b7e_row1_col0, #T_12b7e_row1_col1, #T_12b7e_row1_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_12b7e" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_12b7e_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_12b7e_level0_col1" class="col_heading level0 col1" >validation</th>
#       <th id="T_12b7e_level0_col2" class="col_heading level0 col2" >test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12b7e_row0_col0" class="data row0 col0" >accuracy_score</td>
#       <td id="T_12b7e_row0_col1" class="data row0 col1" >0.945205</td>
#       <td id="T_12b7e_row0_col2" class="data row0 col2" >0.965116</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row1_col0" class="data row1 col0" >custom_metric</td>
#       <td id="T_12b7e_row1_col1" class="data row1 col1" >0.5</td>
#       <td id="T_12b7e_row1_col2" class="data row1 col2" >0.500000</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row2_col0" class="data row2 col0" >example_count</td>
#       <td id="T_12b7e_row2_col1" class="data row2 col1" >73</td>
#       <td id="T_12b7e_row2_col2" class="data row2 col2" >86.000000</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row3_col0" class="data row3 col0" >f1_score</td>
#       <td id="T_12b7e_row3_col1" class="data row3 col1" >0.955556</td>
#       <td id="T_12b7e_row3_col2" class="data row3 col2" >0.975207</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row4_col0" class="data row4 col0" >false_negatives</td>
#       <td id="T_12b7e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_12b7e_row4_col2" class="data row4 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row5_col0" class="data row5 col0" >false_positives</td>
#       <td id="T_12b7e_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_12b7e_row5_col2" class="data row5 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row6_col0" class="data row6 col0" >log_loss</td>
#       <td id="T_12b7e_row6_col1" class="data row6 col1" >0.166907</td>
#       <td id="T_12b7e_row6_col2" class="data row6 col2" >0.148585</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row7_col0" class="data row7 col0" >precision_recall_auc</td>
#       <td id="T_12b7e_row7_col1" class="data row7 col1" >0.995552</td>
#       <td id="T_12b7e_row7_col2" class="data row7 col2" >0.994189</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row8_col0" class="data row8 col0" >precision_score</td>
#       <td id="T_12b7e_row8_col1" class="data row8 col1" >0.955556</td>
#       <td id="T_12b7e_row8_col2" class="data row8 col2" >0.967213</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row9_col0" class="data row9 col0" >recall_score</td>
#       <td id="T_12b7e_row9_col1" class="data row9 col1" >0.955556</td>
#       <td id="T_12b7e_row9_col2" class="data row9 col2" >0.983333</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row10_col0" class="data row10 col0" >roc_auc</td>
#       <td id="T_12b7e_row10_col1" class="data row10 col1" >0.992857</td>
#       <td id="T_12b7e_row10_col2" class="data row10 col2" >0.987821</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row11_col0" class="data row11 col0" >score</td>
#       <td id="T_12b7e_row11_col1" class="data row11 col1" >0.945205</td>
#       <td id="T_12b7e_row11_col2" class="data row11 col2" >0.965116</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row12_col0" class="data row12 col0" >true_negatives</td>
#       <td id="T_12b7e_row12_col1" class="data row12 col1" >26</td>
#       <td id="T_12b7e_row12_col2" class="data row12 col2" >24.000000</td>
#     </tr>
#     <tr>
#       <td id="T_12b7e_row13_col0" class="data row13 col0" >true_positives</td>
#       <td id="T_12b7e_row13_col1" class="data row13 col1" >43</td>
#       <td id="T_12b7e_row13_col2" class="data row13 col2" >59.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div> </div>
#
#                 <div class="content-lx57z5 content-hide"><h3 class='section-title'>Model Validation Results (Test Dataset)</h3> <div style="max-height: 500px; overflow: scroll;"><style type="text/css">
# #T_4cf70 table {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_4cf70  th {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# #T_4cf70  td {
#   border: 1px solid grey;
#   text-align: left;
#   padding: 5px;
# }
# </style>
# <table id="T_4cf70" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th id="T_4cf70_level0_col0" class="col_heading level0 col0" >metric</th>
#       <th id="T_4cf70_level0_col1" class="col_heading level0 col1" >greater_is_better</th>
#       <th id="T_4cf70_level0_col2" class="col_heading level0 col2" >value</th>
#       <th id="T_4cf70_level0_col3" class="col_heading level

# %%
r.run("register")
# Out:
# 2022/11/12 01:00:58 INFO mlflow.recipes.utils.execution: ingest, split, transform, train, evaluate: No changes. Skipping.
# 2022/11/12 01:00:59 INFO mlflow.recipes.step: Running step register...
# Registered model 'model' already exists. Creating a new version of this model...
# 2022/11/12 01:00:59 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: model, version 4
# Created version '4' of model 'model'.
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>Register@recipes-classification-template</title>
#         <style>
#             h1.title {
#             color: #4287f5;
#             }
#             h2.step-title {
#                 color : #4287f5;
#             }
#             .tab {
#                 overflow: hidden;
#                 border: 1px solid #ccc;
#                 background-color: #f1f1f1;
#             }
#
#             .tab button {
#                 background-color: inherit;
#                 float: left;
#                 border: none;
#                 outline: none;
#                 cursor: pointer;
#                 padding: 14px 16px;
#                 transition: 0.3s;
#             }
#
#             .tab button:hover {
#                 background-color: #ddd;
#             }
#
#             .tab button.active {
#                 background-color: #ccc;
#             }
#
#             .tabcontent {
#                 display: block;
#                 padding: 6px 12px;
#                 border: 1px solid #ccc;
#                 border-top: none;
#             }
#
#             .content-hide {
#                 display: none;
#             }
#
#             .content-active {
#                 display: block;
#             }
#             h3.section-title {
#                 color: #57a8de;
#             }
#             .dataset-container {
#                 width: max;
#                 overflow-x: auto;
#                 white-space: nowrap;
#             }
#             .stacktrace-container {
#                 max-height: 300px;
#                 overflow: auto;
#                 display: flex;
#                 flex-direction: column-reverse;
#                 white-space: pre-wrap;
#             }
#         </style>
#     </head>
#    <body>
#         <div class="tab">
#             <div class="button-container-rccnty">
#
#                     <button id=0 class="tablink-rccnty">
#                         Run Summary
#                     </button>
#
#             </div>
#         </div>
#         <div class="tabcontent">
#
#                 <div class="content-rccnty content-hide"><p><strong>Model Name:</strong> <code>model</code></p><p><strong>Model Version:</strong> <code>4</code></p><p><strong>Model Source URI:</strong> <code>runs:/62f37034b8b545b8a2da98d80e631487/train/model</code></p><p><strong>Run duration (s)</strong>: 0.217</p><p><strong>Last updated:</strong> 2022-11-12 01:00:59</p></div>
#
#         </div>
#         <script>
#             function onclickTab(event) {
#                  const tablinks = document.getElementsByClassName("tablink-rccnty");
#                 for (i = 0; i < tablinks.length; i++) {
#                     tablinks[i].className = tablinks[i].className.replace("active", "");
#                 }
#                 event.target.classList.add("active");
#
#                 const tabId = event.target.id;
#                 const tabContents = document.getElementsByClassName("content-rccnty");
#                 for (i = 0; i < tabContents.length; i++) {
#                     tabContents[i].className = tabContents[i].className.replace("content-active", "content-hide");
#                 }
#                 tabContents[tabId].classList.add("content-active");
#             }
#             (function() {
#                 const buttonsContainer = document.getElementsByClassName("button-container-rccnty")[0]
#                 buttonsContainer.addEventListener("click", onclickTab);
#
#                 const tablinks = document.getElementsByClassName("tablink-rccnty");
#                 tablinks[0].classList.add("active");
#                 const tabContents = document.getElementsByClassName("content-rccnty");
#                 tabContents[0].classList.add("content-active");
#             })()
#         </script>
#    </body>
# </html>
